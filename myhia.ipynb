# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/10_3
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/5_3
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/8_2
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/2_1
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/11_1
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/11_3
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/3_2
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/12_3
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/5_1
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/3_1
# /kaggle/input/datasets/wangzixiang1/dataset/dataset/SEED-China/eye_tracking_feature/9_2
# ...

# %%
cd /
# Out:
# /

# %%
# !cp -r /kaggle/input/datasets/wangzixiang1/hia-coder/HIA-code/* /kaggle/working/hia_net/
# Out:
# cp: target '/kaggle/working/hia_net/' is not a directory

# %%
# !cp -r /kaggle/input/datasets/wangzixiang1/hia-coder/HIA-code/* /kaggle/working/hia_net/
# Out:
# cp: target '/kaggle/working/hia_net/' is not a directory

# %%
# %cd /kaggle/working/hia_net
# Out:
# [Errno 2] No such file or directory: '/kaggle/working/hia_net'
# /

# %%
pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-t6m0i8ro
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-t6m0i8ro
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# ...
# ...
# ...
# WARNING: huggingface-hub 1.4.1 does not provide the extra 'hf-transfer'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.7/306.7 kB 5.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python train_franch.py
# Out:
# python3: can't open file '//train_franch.py': [Errno 2] No such file or directory

# %%
# !mkdir -p /kaggle/working/hia_net

# %%
# !cp -r /kaggle/input/datasets/wangzixiang1/hia-coder/HIA-code/* /kaggle/working/hia_net/
